# %% [markdown]
# # MTH229: a Julia installation for MTH229 sans SymPy
# Alternatively [![run on Binder with SymPy](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/mth229/229-projects/lite?labpath=blank-notebook.ipynb)

# %%
using MTH229Lite # loads several packages, a plotting package, but no SymPy
